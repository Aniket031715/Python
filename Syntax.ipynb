# %% [markdown]
# #Basic Syntax

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# Writing "" in  a print

# %%
print("\"Hello World!\"")
# Out:
# "Hello World!"

# %%
print("This is the first line", end = " ")
print("This will be printed on the same line")
# Out:
# This is the first line This will be printed on the same line

# %% [markdown]
# Numbers

# %%
print(3)
print(3+3)
print(2*3)
print(4/2)
a = 3
print(a*a)
print(a)
print("The number is : ", a)
print("I am number : ",4, "and You are number : ", 3)
# Out:
# 3
# 6
# 6
# 2.0
# 9
# 3
# The number is :  3
# I am number :  4 and You are number :  3

# %% [markdown]
# Python Indetation

# %% [markdown]
# Python requires proper spacing between lines to see branches

# %%
if 5 > 2:
    print("true")
# Out:
# true

# %% [markdown]
# Variables

# %%
x = 5

y = "Hello"

# %% [markdown]
# Comments

# %%
#This is an comments

# %%
"""
This is a comment
written in
more than just one line
"""
# Out:
# '\nThis is a comment\nwritten in\nmore than just one line\n'

# %%
"""
This is a comment
written in
more than just one line
"""
print("Now because of this the comment won't be shown")
# Out:
# Now because of this the comment won't be shown

# %% [markdown]
# ## Basic Knowledge

# %% [markdown]
# ### File Handling
#     The key function for working with files in Python is the open() function.
#
#     The open() function takes two parameters; filename, and mode.
#
#     There are four different methods (modes) for opening a file:
#
#     "r" - Read - Default value. Opens a file for reading, error if the file does not exist
#
#     "a" - Append - Opens a file for appending, creates the file if it does not exist
#
#     "w" - Write - Opens a file for writing, creates the file if it does not exist
#
#     "x" - Create - Creates the specified file, returns an error if the file exists
#
#     In addition you can specify if the file should be handled as binary or text mode
#
#     "t" - Text - Default value. Text mode
#
#     "b" - Binary - Binary mode (e.g. images)

# %%
f = open("LearningFH.txt")

# %%
f = open("LearningFH.txt", "rt")

# %% [markdown]
# # Read a file

# %%
print(f.read())
# Out:
# Hello, This should be printed when I read the file in python!!

# %% [markdown]
# # Call a file from different folder

# %%
new_f = open(r"C:\\Users\anike\Documents\Python\07-FileManagement\ExtraFolderTest\a.txt", "rt") # the r tells the \a \p in the folder list are not escape characters like \n

# %% [markdown]
# # Read a part of the file

# %%
print(f.read(1)) # when i run it next time next part of the same size will be read
# Out:
# H

# %% [markdown]
# # Read Lines

# %%
print(f.readline())
print(f.readline())
# Out:
# Hello, This should be printed when I read the file in python!!
#
# This is the secondline

# %%
for x in f:
    print(x)
# Out:
# Hello, This should be printed when I read the file in python!!
#
# This is the secondline

# %% [markdown]
# # Write in a file

# %%
f = open("LearningFH.txt","a")

f.write("\nNow the file has more content!!!")

f = open("LearningFH.txt","r")

print(f.read())
# Out:
# Hello, This should be printed when I read the file in python!!
# This is the secondline
# Now the file has more content!!!Now the file has more content!!!Now the file has more content!!!
# Now the file has more content!!!
# Now the file has more content!!!
# Now the file has more content!!!
# Now the file has more content!!!
# Now the file has more content!!!
# Now the file has more content!!!
# Now the file has more content!!!
# Now the file has more content!!!
# Now the file has more content!!!
# Now the file has more content!!!
# Now the file has more content!!!
# Now the file has more content!!!
# Now the file has more content!!!

# %% [markdown]
# # creating a file

# %%
f = open("FH_creation.txt", "a") #this will create a new file only if it does not exist

# %%
f = open("FH_creation.txt", "x") #if a file already exists it will return error
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 f = open("FH_creation.txt", "x")
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'FH_creation.txt'

# %% [markdown]
# # Deleting a file

# %%
import os
if os.path.exists("Deletingtest.txt"):
    print("The file exists now we will remove it")
    os.remove("Deletingtest.txt")
else:
  print("The file does not exist")

# this will check if the file exists or not
# Out:
# The file exists now we will remove it

# %% [markdown]
# # Delecting entire folder

# %%
import os
if os.path.exists("RMDIR"):
    print("The folder exists now we will remove it")
    os.rmdir("RMDIR")
else:
  print("The file does not exist")

# this will check if the file exists or not
# Out:
# The folder exists now we will remove it
